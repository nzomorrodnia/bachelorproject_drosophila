# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(style="darkgrid")

# %%
import os
os.getcwd()
# Out:
# '/Users/ninazomorrodnia/Documents/bachelorproject_drosophila'

# %%
#Finding path to file
PATH = '/Users/ninazomorrodnia/Desktop/Bachelorprojekt/Data - february + march/Phosphoproteomics Data/'
FILE = PATH + '/Heat map data of phophopro in both CHO and Protein.xlsx'

#Reading in file as excel
#df_chol_prot_data = pd.read_excel(FILE)

#PATH2 = '/Users/ninazomorrodnia/Desktop/'

#DATA_PATH = '/home/williamtheodor/Documents/Private/Drosophila/Data/'
#FILE_PATH = DATA_PATH + '/Heat map data of phophopro in both CHO and Protein.xlsx'
#FILE_PATH2 = DATA_PATH + '/Kim April samples Phosphopeptides with names (Tub x W, HR3-i, TOR-i synth refeeding) (1).xlsx'

#Reading in file as excel
df_chol_prot_data = pd.read_excel(FILE)
#df_new_phospho = pd.read_excel(FILE_PATH2)
df_chol_prot_data.head()
#df_new_phospho.head()
# Out:
#   Gene Name                                            Protien  \
# 0       NaN                                      Modifications
# 1       Acn  1xTMTpro [K1]; 1xTMTpro [N-Term]; 1xPhospho [S...
# 2       NaN  2xTMTpro [K5; K9]; 1xTMTpro [N-Term]; 1xPhosph...
# 3       NaN  1xTMTpro [K17]; 1xTMTpro [N-Term]; 1xPhospho [...
# 4       NaN  3xTMTpro [K4; K8; K9]; 1xTMTpro [N-Term]; 1xPh...
#
#         Unnamed: 2                     Unnamed: 3  \
# 0  ASSOCIATED_GENE  Abundance Ratio: (T15) / (T0)
# 1              Acn                          0.736
# 2              Acn                          1.124
# 3              Acn                          0.856
# 4              Acn                          1.502
#
#                       Unnamed: 4                    Unnamed: 5  \
# 0  Abundance Ratio: (T30) / (T0)  Abundance Ratio: (T1) / (T0)
# 1                          1.712                          2.69
# 2                          2.602                         3.821
# ...

# %%
temp = np.unique([name for name in np.unique(list(df_chol_prot_data['Unnamed: 2']))])
print(len(temp))
temp
# Out:
# 127
# array(['ASSOCIATED_GENE', 'Acn', 'Acn-PC', 'Ae2', 'Ae2-PF', 'Alp4',
#        'Alp4-PA', 'Amph', 'Amph-PA', 'Apoltp', 'Apoltp-PC', 'Ars2',
#        'Ars2-PD', 'Atg17-PC', 'Atu', 'Atu-PA', 'B52-PO', 'BicD-PD', 'CAP',
#        'CAP-PAA', 'CAP-PAE', 'CAP-PR', 'CG10341-PA', 'CG10353-PF',
#        'CG10737', 'CG10737-PT', 'CG10737-PY', 'CG10912-PA', 'CG12065',
#        'CG12065-PE', 'CG12065-PG', 'CG12105-PA', 'CG12576-PE', 'CG13907',
#        'CG13907-PA', 'CG14445-PC', 'CG1674', 'CG1674-PB', 'CG1674-PH',
#        'CG1677', 'CG1677-PC', 'CG16903', 'CG16903-PA', 'CG1703',
#        'CG1703-PA', 'CG17168', 'CG17168-PA', 'CG18304', 'CG18304-PD',
#        'CG2556', 'CG2556-PA', 'CG2681', 'CG2681-PA', 'CG2841-PF',
#        'CG2926', 'CG2926-PA', 'CG30122-PC', 'CG42672', 'CG42672-PP',
#        'CG44245', 'CG44245-PB', 'CG45076', 'CG45076-PE', 'CG45076-PH',
#        'CG5270-PB', 'CG5381', 'CG5381-PC', 'CG5787-PB', 'CG8289',
# ...

# %%
all_genes_p = df_chol_prot_data[['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9']].dropna()
all_genes_p = all_genes_p.to_numpy()[1:]

all_genes_c = df_chol_prot_data[['Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25']].dropna()
all_genes_c = all_genes_c.to_numpy()[1:]

plt.plot(all_genes_p.mean(axis=0))
plt.plot(all_genes_c.mean(axis=0))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming all_genes is a numpy array containing the gene expression data

fig, ax = plt.subplots(1,1,figsize=(12,6))

mean_labels = ['Mean Protein diet', 'Mean cholesterol diet']
std_labels = ['Standard Deviation Protein diet', 'Standard Deviation Cholesterol diet']

for i, genes in enumerate([all_genes_p, all_genes_c]):

    # Calculating the mean and standard error
    mean_values = genes.mean(axis=0)
    std_errors = genes.var(axis=0) / np.sqrt(genes.shape[0])  # Standard error = standard deviation / sqrt(sample size)

    # Setting the confidence level (e.g., 95%)
    confidence_level = 0.95

    # Calculating the margin of error (z-score * standard error)
    z_score = 1.96  # For a 95% confidence level
    margin_of_error = z_score * std_errors

    # Calculating the lower and upper bound of the confidence interval
    lower_bounds = mean_values - margin_of_error
    upper_bounds = mean_values + margin_of_error

    lower_bounds = lower_bounds.astype(float)
    upper_bounds = upper_bounds.astype(float)

    ax.plot(mean_values, label=mean_labels[i])
    ax.fill_between(range(len(mean_values)), lower_bounds, upper_bounds, alpha=0.3, label=std_labels[i])

    # Rest of the code

    # Adding labels and title to the plot
    ax.set_xlabel('Time')
    ax.set_ylabel('Abundance Ratio (Phosphorylation level)')
    ax.set_title('Protein phosphorylation over time with Confidence Intervals')

    xlabels = ['15 min.', '30 min.', '1 hour', '2 hours', '4 hours', '6 hours', '10 hours']
    ax.set_xticks([0,1,2,3,4,5,6])
    ax.set_xticklabels(xlabels)

    # Adding a legend
    ax.legend()

# Displaying the plot
plt.show()

# %%
sub_df = df_chol_prot_data[df_chol_prot_data['Unnamed: 2'] == 'Acn-PC']
sub_df_prot = sub_df[['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9']]

data = sub_df_prot.to_numpy()

# %%
data
# Out:
# array([[0.956, 1.471, 1.858, 2.208, 1.548, 1.93, 1.269],
#        [0.859, 1.526, 1.722, 1.931, 1.78, 1.812, 1.516],
#        [1.127, 1.326, 1.58, 1.82, 1.54, 1.84, 1.581],
#        [1.014, 1.031, 1.113, 1.235, 1.574, 1.421, 1.561],
#        [1.159, 1.129, 1.409, 1.44, 1.542, 1.391, 1.329],
#        [1.53, 0.733, 0.496, 0.347, 0.488, 0.36, 0.505],
#        [0.802, 1.169, 1.023, 1.037, 1.317, 1.332, 1.514],
#        [1.356, 0.858, 0.783, 0.792, 1.092, 0.741, 0.802],
#        [0.789, 1.216, 1.197, 1.319, 1.347, 1.215, 1.247],
#        [1.222, 1.339, 1.161, 0.884, 0.617, 0.548, 0.347],
#        [1.337, 0.96, 0.706, 0.651, 0.887, 0.709, 0.846],
#        [1.054, 0.881, 0.856, 0.867, 1.231, 0.903, 0.923],
#        [1.209, 0.832, 0.62, 0.577, 0.791, 0.716, 0.942],
#        [0.927, 0.826, 0.855, 1.006, 1.18, 1.063, 1.126],
#        [0.909, 0.918, 0.892, 0.874, 1.016, 0.969, 1.168],
#        [1.056, 1.163, 1.032, 0.973, 0.969, 1.027, 0.995],
# ...

# %%
plt.plot(data.mean(axis=0))

# %%
mu = data.mean(axis=1)

#some confidence interval
#ci = 1.96 * data.std(axis=0)/data.shape[0]

fig, ax = plt.subplots()
ax.plot(data)
#ax.fill_between(x, (y-ci), (y+ci), color='b', alpha=.1)


#plt.plot()

# %%
df_new_phospho
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_new_phospho
#
# NameError: name 'df_new_phospho' is not defined

# %%
# dataset is stored in a variable called 'df_CHOLESTEROL'
# Creating a new dataset by filtering rows based on the condition
new_dataset_cholesterol = df_CHOLESTEROL[df_CHOLESTEROL['Master Protein Descriptions'].str.startswith('Insulin', na=False)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10554/2064183062.py in <module>
#       1 # dataset is stored in a variable called 'df_CHOLESTEROL'
#       2 # Creating a new dataset by filtering rows based on the condition
# ----> 3 new_dataset_cholesterol = df_CHOLESTEROL[df_CHOLESTEROL['Master Protein Descriptions'].str.startswith('Insulin', na=False)]
#
# NameError: name 'df_CHOLESTEROL' is not defined

# %%
# Create a new dataset by filtering rows based on the condition
filtered_new_phospho = df_new_phospho[df_new_phospho['Unnamed: 3'].str.startswith(('IRSp53', 'chico'))]

# %%
filtered_new_phospho.head()

# %%
import os
os.getcwd()

os.chdir('/Users/ninazomorrodnia/Desktop')

# %%
# Downloading the file as csv file
filtered_new_phospho.to_csv('filtered_new_phospho')
